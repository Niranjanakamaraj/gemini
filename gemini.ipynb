# %% [markdown]
# <a href="https://colab.research.google.com/github/Niranjanakamaraj/gemini/blob/main/gemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -q -U google-generativeai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.8/160.8 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 760.0/760.0 kB 17.1 MB/s eta 0:00:00

# %%
import pathlib
import textwrap
import google.generativeai as genai
# Used to securely store your API key
from google.colab import userdata
from IPython.display import display
from IPython.display import Markdown
def to_markdown (text):
  text= text.replace('.',' *')
  return Markdown (textwrap.indent (text, '> ', predicate=lambda _: True))

# %%
import os
os.environ["GOOGLE_API_KEY"]="AIzaSyBwZuIt4Wudea9gbCJbvTyQlUfMxeDBpQw"

# %%
genai.configure(api_key=os.environ['GOOGLE_API_KEY'])

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
# %%time
response = model.generate_content("what is the gemini and its history")
# Out:
# CPU times: user 119 ms, sys: 15.4 ms, total: 134 ms
# Wall time: 9.15 s

# %%
response
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
# ...

# %%
to_markdown(response.text)
# Out:
# > **The Gemini Constellation**
# >
# > **Description:**
# >
# > Gemini, the Twins, is a constellation located in the northern celestial hemisphere * It consists of two bright stars representing the heads of the twins, Castor and Pollux, and several other fainter stars *
# >
# > **History:**
# >
# > * **Ancient Mesopotamia:** In ancient Mesopotamia (c * 3000 BC), the constellation was known as "the Great Twins" and was associated with the gods Lugalirra and Meslamtaea *
# > * **Greek Mythology:** In Greek mythology, the constellation represents the twins Castor and Pollux, the sons of Leda and Zeus * Castor was a mortal skilled in fighting, while Pollux was an immortal skilled in wrestling *
# > * **Roman Empire:** The Roman Empire adopted the Greek mythology and referred to the constellation as "Gemini *"
# > * **Medieval Europe:** During the Middle Ages, Gemini was one of the 48 constellations listed by Ptolemy in his Almagest *
# ...

# %%
response.prompt_feedback

# %%
response.candidates
# Out:
# [content {
#   parts {
# ...

# %%
for chunk in response:
  print(chunk.text)
  print("_"*80)
# Out:
# **The Gemini Constellation**
#
# **Description:**
#
# Gemini, the Twins, is a constellation located in the northern celestial hemisphere. It consists of two bright stars representing the heads of the twins, Castor and Pollux, and several other fainter stars.
#
# **History:**
#
# * **Ancient Mesopotamia:** In ancient Mesopotamia (c. 3000 BC), the constellation was known as "the Great Twins" and was associated with the gods Lugalirra and Meslamtaea.
# * **Greek Mythology:** In Greek mythology, the constellation represents the twins Castor and Pollux, the sons of Leda and Zeus. Castor was a mortal skilled in fighting, while Pollux was an immortal skilled in wrestling.
# * **Roman Empire:** The Roman Empire adopted the Greek mythology and referred to the constellation as "Gemini."
# * **Medieval Europe:** During the Middle Ages, Gemini was one of the 48 constellations listed by Ptolemy in his Almagest.
# ...

# %%
import PIL.Image
img=PIL.Image.open('/content/Screenshot (3).png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=622x372>

# %%
model=genai.GenerativeModel('gemini-1.5-flash')

# %%
response = model.generate_content(img)
to_markdown(response.text)
# Out:
# > This is a beautiful image of a Ganesh idol * Ganesh is a Hindu god known for wisdom, prosperity, and good fortune * He is often depicted with an elephant head, a single tusk, and a large belly * The idol in this image is adorned with elaborate jewelry and flowers * He is sitting on a platform decorated with vibrant colors * The image evokes a sense of peace, tranquility, and devotion *
# >
# > It is a common practice for Hindus to worship Ganesh during festivals like Ganesh Chaturthi * This is a ten-day festival that celebrates the birth of Ganesh * During this time, people create idols of Ganesh and offer prayers and worship to him * This image beautifully captures the spirit of devotion and celebration associated with Ganesh worship *

# %%
response = model.generate_content(["write a short blog based on this picture",img],stream=True)
response.resolve()

# %%
to_markdown(response.text)
# Out:
# > ## The Adorable Lord Ganesha
# >
# > This image captures the beauty and charm of Lord Ganesha, the elephant-headed god revered in Hinduism * This particular statue is exceptionally captivating with its intricate details and vibrant colors *
# >
# > The statue is adorned with exquisite jewelry, including necklaces, earrings, and bracelets, all crafted with sparkling rhinestones and gold * The peacock feathers behind Ganesha add a touch of elegance and symbolize wisdom and prosperity *
# >
# > Ganesha's gentle expression and the "Om" symbol inscribed on his hand radiate a sense of peace and blessings * The little "modak" (a traditional Indian sweet) in his hand represents his love for sweets and his role as the remover of obstacles *
# >
# > This statue serves as a beautiful reminder of the divine and the importance of seeking knowledge, wisdom, and success in life *
